# %%
def suml(l):
    if type(l) is list:        
        i=0
        x=l[0]
        if len(l) == 1:
            x=l[0]
        elif len(l) == 2:  
            x = x + l[i+1]
        else: 
            for i in range(1,len(l)):
                x = x + l[i]
                i+=1
    else:
        x = "input a valid list sequence"
    return x

# %%
l = [1,3,4,9]

# %%
suml(l)
